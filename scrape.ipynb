# %%
## load in the lib
import requests
from bs4 import BeautifulStoneSoup as bs

# %% [markdown]
# Load in the webpage

# %%
# load webpage content
r = requests.get("https://pokemondb.net/move/will-o-wisp")

#convert to a bsoup object
soup = bs(r.content)

#print html
print(soup)

# %% [markdown]
# Using Bsoup to scrape

# %%
#searchs page for the body stuff
body = soup.find('body')
#searchs the body for examples of the a tag with the class ent-name. This gives us the names of hte pokemon that can learn the move
pokeNames = body.find_all('a', {'class':'ent-name'})
for title in pokeNames:
    print(title.text)

# %% [markdown]
# Now I am going to try and write something that will cycle through the intial page and do the above function

# %%
## load in the lib
import requests
from bs4 import BeautifulStoneSoup as bs

# load webpage content
r = requests.get("https://pokemondb.net/move/all")

#convert to a bsoup object
soupymoves = bs(r.content)

pokeMoves = soupymoves.find_all('a', {'class':'ent-name'})
for title in pokeMoves:
    print(title.text)

len(pokeMoves)

# %% [markdown]
# url getter

# %%
#Example of a workering one

# import necessary libraries
from bs4 import BeautifulSoup
import requests
import re
  
  
# function to extract html document from given url
def getHTMLdocument(url):
      
    # request for HTML document of given url
    response = requests.get(url)
      
    # response will be provided in JSON format
    return response.text
  
    
# assign required credentials
# assign URL
url_to_scrape = "https://practice.geeksforgeeks.org/courses/"
  
# create document
html_document = getHTMLdocument(url_to_scrape)
  
# create soap object
soup = BeautifulSoup(html_document, 'html.parser')
  
  
# find all the anchor tags with "href" 
# attribute starting with "https://"
for link in soup.find_all('a', 
                          attrs={'href': re.compile("^https://")}):
    # display the actual urls
    print(link.get('href'))
# Out:
# https://www.geeksforgeeks.org/
# https://www.facebook.com/geeksforgeeks.org/
# https://www.instagram.com/geeks_for_geeks/
# https://in.linkedin.com/company/geeksforgeeks
# https://twitter.com/geeksforgeeks
# https://www.youtube.com/geeksforgeeksvideos
# https://www.geeksforgeeks.org/about/
# https://www.geeksforgeeks.org/careers/
# https://www.geeksforgeeks.org/privacy-policy/
# https://www.geeksforgeeks.org/about/contact-us/
# https://practice.geeksforgeeks.org/terms-of-service/
# https://www.geeksforgeeks.org/fundamentals-of-algorithms/
# https://www.geeksforgeeks.org/data-structures/
# https://www.geeksforgeeks.org/category/program-output/
# https://www.geeksforgeeks.org/articles-on-computer-science-subjects-gq/
# https://www.youtube.com/geeksforgeeksvideos/
# https://practice.geeksforgeeks.org/courses/
# https://practice.geeksforgeeks.org/company-tags/
# https://practice.geeksforgeeks.org/topic-tags/
# https://practice.geeksforgeeks.org/faq.php
# https://www.geeksforgeeks.org/contribute/
# https://www.geeksforgeeks.org/write-interview-experience/
# https://www.geeksforgeeks.org/internship/
# https://www.geeksforgeeks.org/how-to-contribute-videos-to-geeksforgeeks/
# https://www.geeksforgeeks.org/
# https://www.geeksforgeeks.org/copyright-information/

# %%
# import necessary libraries
from bs4 import BeautifulSoup
import requests
import re
  
  
# function to extract html document from given url
def getHTMLdocument(url):
      
    # request for HTML document of given url
    response = requests.get(url)
      
    # response will be provided in JSON format
    return response.text
  
    
# assign required credentials
# assign URL
url_to_scrape = "https://pokemondb.net/move/all"
  
# create document
html_document = getHTMLdocument(url_to_scrape)
  
# create soap object
soup = BeautifulSoup(html_document, 'html.parser')
  
  
# find all the anchor tags with "ent-name" 
# attribute starting with "/move/(whatevermove)"
for link in soup.find_all('a',
                            attrs={'href': re.compile("/move/")}):
    # display the actual urls?????????
    links = (link.get('href'))
    print( "https://pokemondb.net" + links)


    #.append('https://pokemondb.net/'))
# Out:
# https://pokemondb.net/move/10000000-volt-thunderbolt
# https://pokemondb.net/move/absorb
# https://pokemondb.net/move/accelerock
# https://pokemondb.net/move/acid
# https://pokemondb.net/move/acid-armor
# https://pokemondb.net/move/acid-downpour
# https://pokemondb.net/move/acid-spray
# https://pokemondb.net/move/acrobatics
# https://pokemondb.net/move/acupressure
# https://pokemondb.net/move/aerial-ace
# https://pokemondb.net/move/aeroblast
# https://pokemondb.net/move/after-you
# https://pokemondb.net/move/agility
# https://pokemondb.net/move/air-cutter
# https://pokemondb.net/move/air-slash
# https://pokemondb.net/move/all-out-pummeling
# https://pokemondb.net/move/ally-switch
# https://pokemondb.net/move/amnesia
# https://pokemondb.net/move/anchor-shot
# https://pokemondb.net/move/ancient-power
# https://pokemondb.net/move/apple-acid
# https://pokemondb.net/move/aqua-jet
# https://pokemondb.net/move/aqua-ring
# https://pokemondb.net/move/aqua-tail
# https://pokemondb.net/move/arm-thrust
# https://pokemondb.net/move/aromatherapy
# https://pokemondb.net/move/aromatic-mist
# https://pokemondb.net/move/assist
# https://pokemondb.net/move/assurance
# https://pokemondb.net/move/astonish
# https://pokemondb.net/move/astral-barrage
# https://pokemondb.net/move/attack-order
# https://pokemondb.net/move/attract
# https://pokemondb.net/move/aura-sphere
# https://pokemondb.net/move/aura-wheel
# https://pokemondb.net/move/aurora-beam
# https://pokemondb.net/move/aurora-veil
# https://pokemondb.net/move/autotomize
# https://pokemondb.net/move/avalanche
# https://pokemondb.net/move/baby-doll-eyes
# https://pokemondb.net/move/baddy-bad
# https://pokemondb.net/move/baneful-bunker
# https://pokemondb.net/move/barb-barrage
# https://pokemondb.net/move/barrage
# https://pokemondb.net/move/barrier
# https://pokemondb.net/move/baton-pass
# https://pokemondb.net/move/beak-blast
# https://pokemondb.net/move/beat-up
# https://pokemondb.net/move/behemoth-bash
# https://pokemondb.net/move/behemoth-blade
# https://pokemondb.net/move/belch
# https://pokemondb.net/move/belly-drum
# https://pokemondb.net/move/bestow
# https://pokemondb.net/move/bide
# https://pokemondb.net/move/bind
# https://pokemondb.net/move/bite
# https://pokemondb.net/move/bitter-malice
# https://pokemondb.net/move/black-hole-eclipse
# https://pokemondb.net/move/blast-burn
# https://pokemondb.net/move/blaze-kick
# https://pokemondb.net/move/bleakwind-storm
# https://pokemondb.net/move/blizzard
# https://pokemondb.net/move/block
# https://pokemondb.net/move/bloom-doom
# https://pokemondb.net/move/blue-flare
# https://pokemondb.net/move/body-press
# https://pokemondb.net/move/body-slam
# https://pokemondb.net/move/bolt-beak
# https://pokemondb.net/move/bolt-strike
# https://pokemondb.net/move/bone-club
# https://pokemondb.net/move/bone-rush
# https://pokemondb.net/move/bonemerang
# https://pokemondb.net/move/boomburst
# https://pokemondb.net/move/bounce
# https://pokemondb.net/move/bouncy-bubble
# https://pokemondb.net/move/branch-poke
# https://pokemondb.net/move/brave-bird
# https://pokemondb.net/move/breaking-swipe
# https://pokemondb.net/move/breakneck-blitz
# https://pokemondb.net/move/brick-break
# https://pokemondb.net/move/brine
# https://pokemondb.net/move/brutal-swing
# https://pokemondb.net/move/bubble
# https://pokemondb.net/move/bubble-beam
# https://pokemondb.net/move/bug-bite
# https://pokemondb.net/move/bug-buzz
# https://pokemondb.net/move/bulk-up
# https://pokemondb.net/move/bulldoze
# https://pokemondb.net/move/bullet-punch
# https://pokemondb.net/move/bullet-seed
# https://pokemondb.net/move/burn-up
# https://pokemondb.net/move/burning-jealousy
# https://pokemondb.net/move/buzzy-buzz
# https://pokemondb.net/move/calm-mind
# https://pokemondb.net/move/camouflage
# https://pokemondb.net/move/captivate
# https://pokemondb.net/move/catastropika
# https://pokemondb.net/move/ceaseless-edge
# https://pokemondb.net/move/celebrate
# https://pokemondb.net/move/charge
# https://pokemondb.net/move/charge-beam
# https://pokemondb.net/move/charm
# https://pokemondb.net/move/chatter
# https://pokemondb.net/move/chip-away
# https://pokemondb.net/move/chloroblast
# https://pokemondb.net/move/circle-throw
# https://pokemondb.net/move/clamp
# https://pokemondb.net/move/clanging-scales
# https://pokemondb.net/move/clangorous-soul
# https://pokemondb.net/move/clangorous-soulblaze
# https://pokemondb.net/move/clear-smog
# https://pokemondb.net/move/close-combat
# https://pokemondb.net/move/coaching
# https://pokemondb.net/move/coil
# https://pokemondb.net/move/comet-punch
# https://pokemondb.net/move/confide
# https://pokemondb.net/move/confuse-ray
# https://pokemondb.net/move/confusion
# https://pokemondb.net/move/constrict
# https://pokemondb.net/move/continental-crush
# https://pokemondb.net/move/conversion
# https://pokemondb.net/move/conversion-2
# https://pokemondb.net/move/copycat
# https://pokemondb.net/move/core-enforcer
# https://pokemondb.net/move/corkscrew-crash
# https://pokemondb.net/move/corrosive-gas
# https://pokemondb.net/move/cosmic-power
# https://pokemondb.net/move/cotton-guard
# https://pokemondb.net/move/cotton-spore
# https://pokemondb.net/move/counter
# https://pokemondb.net/move/court-change
# https://pokemondb.net/move/covet
# https://pokemondb.net/move/crabhammer
# https://pokemondb.net/move/crafty-shield
# https://pokemondb.net/move/cross-chop
# https://pokemondb.net/move/cross-poison
# https://pokemondb.net/move/crunch
# https://pokemondb.net/move/crush-claw
# https://pokemondb.net/move/crush-grip
# https://pokemondb.net/move/curse
# https://pokemondb.net/move/cut
# https://pokemondb.net/move/dark-pulse
# https://pokemondb.net/move/dark-void
# https://pokemondb.net/move/darkest-lariat
# https://pokemondb.net/move/dazzling-gleam
# https://pokemondb.net/move/decorate
# https://pokemondb.net/move/defend-order
# https://pokemondb.net/move/defense-curl
# https://pokemondb.net/move/defog
# https://pokemondb.net/move/destiny-bond
# https://pokemondb.net/move/detect
# https://pokemondb.net/move/devastating-drake
# https://pokemondb.net/move/diamond-storm
# https://pokemondb.net/move/dig
# https://pokemondb.net/move/dire-claw
# https://pokemondb.net/move/disable
# https://pokemondb.net/move/disarming-voice
# https://pokemondb.net/move/discharge
# https://pokemondb.net/move/dive
# https://pokemondb.net/move/dizzy-punch
# https://pokemondb.net/move/doom-desire
# https://pokemondb.net/move/double-hit
# https://pokemondb.net/move/double-iron-bash
# https://pokemondb.net/move/double-kick
# https://pokemondb.net/move/double-slap
# https://pokemondb.net/move/double-team
# https://pokemondb.net/move/double-edge
# https://pokemondb.net/move/draco-meteor
# https://pokemondb.net/move/dragon-ascent
# https://pokemondb.net/move/dragon-breath
# https://pokemondb.net/move/dragon-claw
# https://pokemondb.net/move/dragon-dance
# https://pokemondb.net/move/dragon-darts
# https://pokemondb.net/move/dragon-energy
# https://pokemondb.net/move/dragon-hammer
# https://pokemondb.net/move/dragon-pulse
# https://pokemondb.net/move/dragon-rage
# https://pokemondb.net/move/dragon-rush
# https://pokemondb.net/move/dragon-tail
# https://pokemondb.net/move/drain-punch
# https://pokemondb.net/move/draining-kiss
# https://pokemondb.net/move/dream-eater
# https://pokemondb.net/move/drill-peck
# https://pokemondb.net/move/drill-run
# https://pokemondb.net/move/drum-beating
# https://pokemondb.net/move/dual-chop
# https://pokemondb.net/move/dual-wingbeat
# https://pokemondb.net/move/dynamax-cannon
# https://pokemondb.net/move/dynamic-punch
# https://pokemondb.net/move/earth-power
# https://pokemondb.net/move/earthquake
# https://pokemondb.net/move/echoed-voice
# https://pokemondb.net/move/eerie-impulse
# https://pokemondb.net/move/eerie-spell
# https://pokemondb.net/move/egg-bomb
# https://pokemondb.net/move/electric-terrain
# https://pokemondb.net/move/electrify
# https://pokemondb.net/move/electro-ball
# https://pokemondb.net/move/electroweb
# https://pokemondb.net/move/embargo
# https://pokemondb.net/move/ember
# https://pokemondb.net/move/encore
# https://pokemondb.net/move/endeavor
# https://pokemondb.net/move/endure
# https://pokemondb.net/move/energy-ball
# https://pokemondb.net/move/entrainment
# https://pokemondb.net/move/eruption
# https://pokemondb.net/move/esper-wing
# https://pokemondb.net/move/eternabeam
# https://pokemondb.net/move/expanding-force
# https://pokemondb.net/move/explosion
# https://pokemondb.net/move/extrasensory
# https://pokemondb.net/move/extreme-evoboost
# https://pokemondb.net/move/extreme-speed
# https://pokemondb.net/move/facade
# https://pokemondb.net/move/fairy-lock
# https://pokemondb.net/move/fairy-wind
# https://pokemondb.net/move/fake-out
# https://pokemondb.net/move/fake-tears
# https://pokemondb.net/move/false-surrender
# https://pokemondb.net/move/false-swipe
# https://pokemondb.net/move/feather-dance
# https://pokemondb.net/move/feint
# https://pokemondb.net/move/feint-attack
# https://pokemondb.net/move/fell-stinger
# https://pokemondb.net/move/fiery-dance
# https://pokemondb.net/move/fiery-wrath
# https://pokemondb.net/move/final-gambit
# https://pokemondb.net/move/fire-blast
# https://pokemondb.net/move/fire-fang
# https://pokemondb.net/move/fire-lash
# https://pokemondb.net/move/fire-pledge
# https://pokemondb.net/move/fire-punch
# https://pokemondb.net/move/fire-spin
# https://pokemondb.net/move/first-impression
# https://pokemondb.net/move/fishious-rend
# https://pokemondb.net/move/fissure
# https://pokemondb.net/move/flail
# https://pokemondb.net/move/flame-burst
# https://pokemondb.net/move/flame-charge
# https://pokemondb.net/move/flame-wheel
# https://pokemondb.net/move/flamethrower
# https://pokemondb.net/move/flare-blitz
# https://pokemondb.net/move/flash
# https://pokemondb.net/move/flash-cannon
# https://pokemondb.net/move/flatter
# https://pokemondb.net/move/fleur-cannon
# https://pokemondb.net/move/fling
# https://pokemondb.net/move/flip-turn
# https://pokemondb.net/move/floaty-fall
# https://pokemondb.net/move/floral-healing
# https://pokemondb.net/move/flower-shield
# https://pokemondb.net/move/fly
# https://pokemondb.net/move/flying-press
# https://pokemondb.net/move/focus-blast
# https://pokemondb.net/move/focus-energy
# https://pokemondb.net/move/focus-punch
# https://pokemondb.net/move/follow-me
# https://pokemondb.net/move/force-palm
# https://pokemondb.net/move/foresight
# https://pokemondb.net/move/forests-curse
# https://pokemondb.net/move/foul-play
# https://pokemondb.net/move/freeze-shock
# https://pokemondb.net/move/freeze-dry
# https://pokemondb.net/move/freezing-glare
# https://pokemondb.net/move/freezy-frost
# https://pokemondb.net/move/frenzy-plant
# https://pokemondb.net/move/frost-breath
# https://pokemondb.net/move/frustration
# https://pokemondb.net/move/fury-attack
# https://pokemondb.net/move/fury-cutter
# https://pokemondb.net/move/fury-swipes
# https://pokemondb.net/move/fusion-bolt
# https://pokemondb.net/move/fusion-flare
# https://pokemondb.net/move/future-sight
# https://pokemondb.net/move/g-max-befuddle
# https://pokemondb.net/move/g-max-cannonade
# https://pokemondb.net/move/g-max-centiferno
# https://pokemondb.net/move/g-max-chi-strike
# https://pokemondb.net/move/g-max-cuddle
# https://pokemondb.net/move/g-max-depletion
# https://pokemondb.net/move/g-max-drum-solo
# https://pokemondb.net/move/g-max-finale
# https://pokemondb.net/move/g-max-fireball
# https://pokemondb.net/move/g-max-foam-burst
# https://pokemondb.net/move/g-max-gold-rush
# https://pokemondb.net/move/g-max-gravitas
# https://pokemondb.net/move/g-max-hydrosnipe
# https://pokemondb.net/move/g-max-malodor
# https://pokemondb.net/move/g-max-meltdown
# https://pokemondb.net/move/g-max-one-blow
# https://pokemondb.net/move/g-max-rapid-flow
# https://pokemondb.net/move/g-max-replenish
# https://pokemondb.net/move/g-max-resonance
# https://pokemondb.net/move/g-max-sandblast
# https://pokemondb.net/move/g-max-smite
# https://pokemondb.net/move/g-max-snooze
# https://pokemondb.net/move/g-max-steelsurge
# https://pokemondb.net/move/g-max-stonesurge
# https://pokemondb.net/move/g-max-stun-shock
# https://pokemondb.net/move/g-max-sweetness
# https://pokemondb.net/move/g-max-tartness
# https://pokemondb.net/move/g-max-terror
# https://pokemondb.net/move/g-max-vine-lash
# https://pokemondb.net/move/g-max-volcalith
# https://pokemondb.net/move/g-max-volt-crash
# https://pokemondb.net/move/g-max-wildfire
# https://pokemondb.net/move/g-max-wind-rage
# https://pokemondb.net/move/gastro-acid
# https://pokemondb.net/move/gear-grind
# https://pokemondb.net/move/gear-up
# https://pokemondb.net/move/genesis-supernova
# https://pokemondb.net/move/geomancy
# https://pokemondb.net/move/giga-drain
# https://pokemondb.net/move/giga-impact
# https://pokemondb.net/move/gigavolt-havoc
# https://pokemondb.net/move/glacial-lance
# https://pokemondb.net/move/glaciate
# https://pokemondb.net/move/glare
# https://pokemondb.net/move/glitzy-glow
# https://pokemondb.net/move/grass-knot
# https://pokemondb.net/move/grass-pledge
# https://pokemondb.net/move/grass-whistle
# https://pokemondb.net/move/grassy-glide
# https://pokemondb.net/move/grassy-terrain
# https://pokemondb.net/move/grav-apple
# https://pokemondb.net/move/gravity
# https://pokemondb.net/move/growl
# https://pokemondb.net/move/growth
# https://pokemondb.net/move/grudge
# https://pokemondb.net/move/guard-split
# https://pokemondb.net/move/guard-swap
# https://pokemondb.net/move/guardian-of-alola
# https://pokemondb.net/move/guillotine
# https://pokemondb.net/move/gunk-shot
# https://pokemondb.net/move/gust
# https://pokemondb.net/move/gyro-ball
# https://pokemondb.net/move/hail
# https://pokemondb.net/move/hammer-arm
# https://pokemondb.net/move/happy-hour
# https://pokemondb.net/move/harden
# https://pokemondb.net/move/haze
# https://pokemondb.net/move/head-charge
# https://pokemondb.net/move/head-smash
# https://pokemondb.net/move/headbutt
# https://pokemondb.net/move/headlong-rush
# https://pokemondb.net/move/heal-bell
# https://pokemondb.net/move/heal-block
# https://pokemondb.net/move/heal-order
# https://pokemondb.net/move/heal-pulse
# https://pokemondb.net/move/healing-wish
# https://pokemondb.net/move/heart-stamp
# https://pokemondb.net/move/heart-swap
# https://pokemondb.net/move/heat-crash
# https://pokemondb.net/move/heat-wave
# https://pokemondb.net/move/heavy-slam
# https://pokemondb.net/move/helping-hand
# https://pokemondb.net/move/hex
# https://pokemondb.net/move/hidden-power
# https://pokemondb.net/move/high-horsepower
# https://pokemondb.net/move/high-jump-kick
# https://pokemondb.net/move/hold-back
# https://pokemondb.net/move/hold-hands
# https://pokemondb.net/move/hone-claws
# https://pokemondb.net/move/horn-attack
# https://pokemondb.net/move/horn-drill
# https://pokemondb.net/move/horn-leech
# https://pokemondb.net/move/howl
# https://pokemondb.net/move/hurricane
# https://pokemondb.net/move/hydro-cannon
# https://pokemondb.net/move/hydro-pump
# https://pokemondb.net/move/hydro-vortex
# https://pokemondb.net/move/hyper-beam
# https://pokemondb.net/move/hyper-fang
# https://pokemondb.net/move/hyper-voice
# https://pokemondb.net/move/hyperspace-fury
# https://pokemondb.net/move/hyperspace-hole
# https://pokemondb.net/move/hypnosis
# https://pokemondb.net/move/ice-ball
# https://pokemondb.net/move/ice-beam
# https://pokemondb.net/move/ice-burn
# https://pokemondb.net/move/ice-fang
# https://pokemondb.net/move/ice-hammer
# https://pokemondb.net/move/ice-punch
# https://pokemondb.net/move/ice-shard
# https://pokemondb.net/move/icicle-crash
# https://pokemondb.net/move/icicle-spear
# https://pokemondb.net/move/icy-wind
# https://pokemondb.net/move/imprison
# https://pokemondb.net/move/incinerate
# https://pokemondb.net/move/infernal-parade
# https://pokemondb.net/move/inferno
# https://pokemondb.net/move/inferno-overdrive
# https://pokemondb.net/move/infestation
# https://pokemondb.net/move/ingrain
# https://pokemondb.net/move/instruct
# https://pokemondb.net/move/ion-deluge
# https://pokemondb.net/move/iron-defense
# https://pokemondb.net/move/iron-head
# https://pokemondb.net/move/iron-tail
# https://pokemondb.net/move/jaw-lock
# https://pokemondb.net/move/judgment
# https://pokemondb.net/move/jump-kick
# https://pokemondb.net/move/jungle-healing
# https://pokemondb.net/move/karate-chop
# https://pokemondb.net/move/kinesis
# https://pokemondb.net/move/kings-shield
# https://pokemondb.net/move/knock-off
# https://pokemondb.net/move/lands-wrath
# https://pokemondb.net/move/laser-focus
# https://pokemondb.net/move/lash-out
# https://pokemondb.net/move/last-resort
# https://pokemondb.net/move/lava-plume
# https://pokemondb.net/move/leaf-blade
# https://pokemondb.net/move/leaf-storm
# https://pokemondb.net/move/leaf-tornado
# https://pokemondb.net/move/leafage
# https://pokemondb.net/move/leech-life
# https://pokemondb.net/move/leech-seed
# https://pokemondb.net/move/leer
# https://pokemondb.net/move/lets-snuggle-forever
# https://pokemondb.net/move/lick
# https://pokemondb.net/move/life-dew
# https://pokemondb.net/move/light-of-ruin
# https://pokemondb.net/move/light-screen
# https://pokemondb.net/move/light-that-burns-the-sky
# https://pokemondb.net/move/liquidation
# https://pokemondb.net/move/lock-on
# https://pokemondb.net/move/lovely-kiss
# https://pokemondb.net/move/low-kick
# https://pokemondb.net/move/low-sweep
# https://pokemondb.net/move/lucky-chant
# https://pokemondb.net/move/lunar-blessing
# https://pokemondb.net/move/lunar-dance
# https://pokemondb.net/move/lunge
# https://pokemondb.net/move/luster-purge
# https://pokemondb.net/move/mach-punch
# https://pokemondb.net/move/magic-coat
# https://pokemondb.net/move/magic-powder
# https://pokemondb.net/move/magic-room
# https://pokemondb.net/move/magical-leaf
# https://pokemondb.net/move/magma-storm
# https://pokemondb.net/move/magnet-bomb
# https://pokemondb.net/move/magnet-rise
# https://pokemondb.net/move/magnetic-flux
# https://pokemondb.net/move/magnitude
# https://pokemondb.net/move/malicious-moonsault
# https://pokemondb.net/move/mat-block
# https://pokemondb.net/move/max-airstream
# https://pokemondb.net/move/max-darkness
# https://pokemondb.net/move/max-flare
# https://pokemondb.net/move/max-flutterby
# https://pokemondb.net/move/max-geyser
# https://pokemondb.net/move/max-guard
# https://pokemondb.net/move/max-hailstorm
# https://pokemondb.net/move/max-knuckle
# https://pokemondb.net/move/max-lightning
# https://pokemondb.net/move/max-mindstorm
# https://pokemondb.net/move/max-ooze
# https://pokemondb.net/move/max-overgrowth
# https://pokemondb.net/move/max-phantasm
# https://pokemondb.net/move/max-quake
# https://pokemondb.net/move/max-rockfall
# https://pokemondb.net/move/max-starfall
# https://pokemondb.net/move/max-steelspike
# https://pokemondb.net/move/max-strike
# https://pokemondb.net/move/max-wyrmwind
# https://pokemondb.net/move/me-first
# https://pokemondb.net/move/mean-look
# https://pokemondb.net/move/meditate
# https://pokemondb.net/move/mega-drain
# https://pokemondb.net/move/mega-kick
# https://pokemondb.net/move/mega-punch
# https://pokemondb.net/move/megahorn
# https://pokemondb.net/move/memento
# https://pokemondb.net/move/menacing-moonraze-maelstrom
# https://pokemondb.net/move/metal-burst
# https://pokemondb.net/move/metal-claw
# https://pokemondb.net/move/metal-sound
# https://pokemondb.net/move/meteor-assault
# https://pokemondb.net/move/meteor-beam
# https://pokemondb.net/move/meteor-mash
# https://pokemondb.net/move/metronome
# https://pokemondb.net/move/milk-drink
# https://pokemondb.net/move/mimic
# https://pokemondb.net/move/mind-blown
# https://pokemondb.net/move/mind-reader
# https://pokemondb.net/move/minimize
# https://pokemondb.net/move/miracle-eye
# https://pokemondb.net/move/mirror-coat
# https://pokemondb.net/move/mirror-move
# https://pokemondb.net/move/mirror-shot
# https://pokemondb.net/move/mist
# https://pokemondb.net/move/mist-ball
# https://pokemondb.net/move/misty-explosion
# https://pokemondb.net/move/misty-terrain
# https://pokemondb.net/move/moonblast
# https://pokemondb.net/move/moongeist-beam
# https://pokemondb.net/move/moonlight
# https://pokemondb.net/move/morning-sun
# https://pokemondb.net/move/mountain-gale
# https://pokemondb.net/move/mud-bomb
# https://pokemondb.net/move/mud-shot
# https://pokemondb.net/move/mud-sport
# https://pokemondb.net/move/mud-slap
# https://pokemondb.net/move/muddy-water
# https://pokemondb.net/move/multi-attack
# https://pokemondb.net/move/mystical-fire
# https://pokemondb.net/move/mystical-power
# https://pokemondb.net/move/nasty-plot
# https://pokemondb.net/move/natural-gift
# https://pokemondb.net/move/nature-power
# https://pokemondb.net/move/natures-madness
# https://pokemondb.net/move/needle-arm
# https://pokemondb.net/move/never-ending-nightmare
# https://pokemondb.net/move/night-daze
# https://pokemondb.net/move/night-shade
# https://pokemondb.net/move/night-slash
# https://pokemondb.net/move/nightmare
# https://pokemondb.net/move/no-retreat
# https://pokemondb.net/move/noble-roar
# https://pokemondb.net/move/nuzzle
# https://pokemondb.net/move/oblivion-wing
# https://pokemondb.net/move/obstruct
# https://pokemondb.net/move/oceanic-operetta
# https://pokemondb.net/move/octazooka
# https://pokemondb.net/move/octolock
# https://pokemondb.net/move/odor-sleuth
# https://pokemondb.net/move/ominous-wind
# https://pokemondb.net/move/origin-pulse
# https://pokemondb.net/move/outrage
# https://pokemondb.net/move/overdrive
# https://pokemondb.net/move/overheat
# https://pokemondb.net/move/pain-split
# https://pokemondb.net/move/parabolic-charge
# https://pokemondb.net/move/parting-shot
# https://pokemondb.net/move/pay-day
# https://pokemondb.net/move/payback
# https://pokemondb.net/move/peck
# https://pokemondb.net/move/perish-song
# https://pokemondb.net/move/petal-blizzard
# https://pokemondb.net/move/petal-dance
# https://pokemondb.net/move/phantom-force
# https://pokemondb.net/move/photon-geyser
# https://pokemondb.net/move/pika-papow
# https://pokemondb.net/move/pin-missile
# https://pokemondb.net/move/plasma-fists
# https://pokemondb.net/move/play-nice
# https://pokemondb.net/move/play-rough
# https://pokemondb.net/move/pluck
# https://pokemondb.net/move/poison-fang
# https://pokemondb.net/move/poison-gas
# https://pokemondb.net/move/poison-jab
# https://pokemondb.net/move/poison-powder
# https://pokemondb.net/move/poison-sting
# https://pokemondb.net/move/poison-tail
# https://pokemondb.net/move/pollen-puff
# https://pokemondb.net/move/poltergeist
# https://pokemondb.net/move/pound
# https://pokemondb.net/move/powder
# https://pokemondb.net/move/powder-snow
# https://pokemondb.net/move/power-gem
# https://pokemondb.net/move/power-shift
# https://pokemondb.net/move/power-split
# https://pokemondb.net/move/power-swap
# https://pokemondb.net/move/power-trick
# https://pokemondb.net/move/power-trip
# https://pokemondb.net/move/power-whip
# https://pokemondb.net/move/power-up-punch
# https://pokemondb.net/move/precipice-blades
# https://pokemondb.net/move/present
# https://pokemondb.net/move/prismatic-laser
# https://pokemondb.net/move/protect
# https://pokemondb.net/move/psybeam
# https://pokemondb.net/move/psych-up
# https://pokemondb.net/move/psychic
# https://pokemondb.net/move/psychic-fangs
# https://pokemondb.net/move/psychic-terrain
# https://pokemondb.net/move/psycho-boost
# https://pokemondb.net/move/psycho-cut
# https://pokemondb.net/move/psycho-shift
# https://pokemondb.net/move/psyshield-bash
# https://pokemondb.net/move/psyshock
# https://pokemondb.net/move/psystrike
# https://pokemondb.net/move/psywave
# https://pokemondb.net/move/pulverizing-pancake
# https://pokemondb.net/move/punishment
# https://pokemondb.net/move/purify
# https://pokemondb.net/move/pursuit
# https://pokemondb.net/move/pyro-ball
# https://pokemondb.net/move/quash
# https://pokemondb.net/move/quick-attack
# https://pokemondb.net/move/quick-guard
# https://pokemondb.net/move/quiver-dance
# https://pokemondb.net/move/rage
# https://pokemondb.net/move/rage-powder
# https://pokemondb.net/move/raging-fury
# https://pokemondb.net/move/rain-dance
# https://pokemondb.net/move/rapid-spin
# https://pokemondb.net/move/razor-leaf
# https://pokemondb.net/move/razor-shell
# https://pokemondb.net/move/razor-wind
# https://pokemondb.net/move/recover
# https://pokemondb.net/move/recycle
# https://pokemondb.net/move/reflect
# https://pokemondb.net/move/reflect-type
# https://pokemondb.net/move/refresh
# https://pokemondb.net/move/relic-song
# https://pokemondb.net/move/rest
# https://pokemondb.net/move/retaliate
# https://pokemondb.net/move/return
# https://pokemondb.net/move/revelation-dance
# https://pokemondb.net/move/revenge
# https://pokemondb.net/move/reversal
# https://pokemondb.net/move/rising-voltage
# https://pokemondb.net/move/roar
# https://pokemondb.net/move/roar-of-time
# https://pokemondb.net/move/rock-blast
# https://pokemondb.net/move/rock-climb
# https://pokemondb.net/move/rock-polish
# https://pokemondb.net/move/rock-slide
# https://pokemondb.net/move/rock-smash
# https://pokemondb.net/move/rock-throw
# https://pokemondb.net/move/rock-tomb
# https://pokemondb.net/move/rock-wrecker
# https://pokemondb.net/move/role-play
# https://pokemondb.net/move/rolling-kick
# https://pokemondb.net/move/rollout
# https://pokemondb.net/move/roost
# https://pokemondb.net/move/rototiller
# https://pokemondb.net/move/round
# https://pokemondb.net/move/sacred-fire
# https://pokemondb.net/move/sacred-sword
# https://pokemondb.net/move/safeguard
# https://pokemondb.net/move/sand-attack
# https://pokemondb.net/move/sand-tomb
# https://pokemondb.net/move/sandsear-storm
# https://pokemondb.net/move/sandstorm
# https://pokemondb.net/move/sappy-seed
# https://pokemondb.net/move/savage-spin-out
# https://pokemondb.net/move/scald
# https://pokemondb.net/move/scale-shot
# https://pokemondb.net/move/scary-face
# https://pokemondb.net/move/scorching-sands
# https://pokemondb.net/move/scratch
# https://pokemondb.net/move/screech
# https://pokemondb.net/move/searing-shot
# https://pokemondb.net/move/searing-sunraze-smash
# https://pokemondb.net/move/secret-power
# https://pokemondb.net/move/secret-sword
# https://pokemondb.net/move/seed-bomb
# https://pokemondb.net/move/seed-flare
# https://pokemondb.net/move/seismic-toss
# https://pokemondb.net/move/self-destruct
# https://pokemondb.net/move/shadow-ball
# https://pokemondb.net/move/shadow-bone
# https://pokemondb.net/move/shadow-claw
# https://pokemondb.net/move/shadow-force
# https://pokemondb.net/move/shadow-punch
# https://pokemondb.net/move/shadow-sneak
# https://pokemondb.net/move/sharpen
# https://pokemondb.net/move/shattered-psyche
# https://pokemondb.net/move/sheer-cold
# https://pokemondb.net/move/shell-side-arm
# https://pokemondb.net/move/shell-smash
# https://pokemondb.net/move/shell-trap
# https://pokemondb.net/move/shelter
# https://pokemondb.net/move/shift-gear
# https://pokemondb.net/move/shock-wave
# https://pokemondb.net/move/shore-up
# https://pokemondb.net/move/signal-beam
# https://pokemondb.net/move/silver-wind
# https://pokemondb.net/move/simple-beam
# https://pokemondb.net/move/sing
# https://pokemondb.net/move/sinister-arrow-raid
# https://pokemondb.net/move/sizzly-slide
# https://pokemondb.net/move/sketch
# https://pokemondb.net/move/skill-swap
# https://pokemondb.net/move/skitter-smack
# https://pokemondb.net/move/skull-bash
# https://pokemondb.net/move/sky-attack
# https://pokemondb.net/move/sky-drop
# https://pokemondb.net/move/sky-uppercut
# https://pokemondb.net/move/slack-off
# https://pokemondb.net/move/slam
# https://pokemondb.net/move/slash
# https://pokemondb.net/move/sleep-powder
# https://pokemondb.net/move/sleep-talk
# https://pokemondb.net/move/sludge
# https://pokemondb.net/move/sludge-bomb
# https://pokemondb.net/move/sludge-wave
# https://pokemondb.net/move/smack-down
# https://pokemondb.net/move/smart-strike
# https://pokemondb.net/move/smelling-salts
# https://pokemondb.net/move/smog
# https://pokemondb.net/move/smokescreen
# https://pokemondb.net/move/snap-trap
# https://pokemondb.net/move/snarl
# https://pokemondb.net/move/snatch
# https://pokemondb.net/move/snipe-shot
# https://pokemondb.net/move/snore
# https://pokemondb.net/move/soak
# https://pokemondb.net/move/soft-boiled
# https://pokemondb.net/move/solar-beam
# https://pokemondb.net/move/solar-blade
# https://pokemondb.net/move/sonic-boom
# https://pokemondb.net/move/soul-stealing-7-star-strike
# https://pokemondb.net/move/spacial-rend
# https://pokemondb.net/move/spark
# https://pokemondb.net/move/sparkling-aria
# https://pokemondb.net/move/sparkly-swirl
# https://pokemondb.net/move/spectral-thief
# https://pokemondb.net/move/speed-swap
# https://pokemondb.net/move/spider-web
# https://pokemondb.net/move/spike-cannon
# https://pokemondb.net/move/spikes
# https://pokemondb.net/move/spiky-shield
# https://pokemondb.net/move/spirit-break
# https://pokemondb.net/move/spirit-shackle
# https://pokemondb.net/move/spit-up
# https://pokemondb.net/move/spite
# https://pokemondb.net/move/splash
# https://pokemondb.net/move/splintered-stormshards
# https://pokemondb.net/move/splishy-splash
# https://pokemondb.net/move/spore
# https://pokemondb.net/move/spotlight
# https://pokemondb.net/move/springtide-storm
# https://pokemondb.net/move/stealth-rock
# https://pokemondb.net/move/steam-eruption
# https://pokemondb.net/move/steamroller
# https://pokemondb.net/move/steel-beam
# https://pokemondb.net/move/steel-roller
# https://pokemondb.net/move/steel-wing
# https://pokemondb.net/move/sticky-web
# https://pokemondb.net/move/stockpile
# https://pokemondb.net/move/stoked-sparksurfer
# https://pokemondb.net/move/stomp
# https://pokemondb.net/move/stomping-tantrum
# https://pokemondb.net/move/stone-axe
# https://pokemondb.net/move/stone-edge
# https://pokemondb.net/move/stored-power
# https://pokemondb.net/move/storm-throw
# https://pokemondb.net/move/strange-steam
# https://pokemondb.net/move/strength
# https://pokemondb.net/move/strength-sap
# https://pokemondb.net/move/string-shot
# https://pokemondb.net/move/struggle
# https://pokemondb.net/move/struggle-bug
# https://pokemondb.net/move/stuff-cheeks
# https://pokemondb.net/move/stun-spore
# https://pokemondb.net/move/submission
# https://pokemondb.net/move/substitute
# https://pokemondb.net/move/subzero-slammer
# https://pokemondb.net/move/sucker-punch
# https://pokemondb.net/move/sunny-day
# https://pokemondb.net/move/sunsteel-strike
# https://pokemondb.net/move/super-fang
# https://pokemondb.net/move/superpower
# https://pokemondb.net/move/supersonic
# https://pokemondb.net/move/supersonic-skystrike
# https://pokemondb.net/move/surf
# https://pokemondb.net/move/surging-strikes
# https://pokemondb.net/move/swagger
# https://pokemondb.net/move/swallow
# https://pokemondb.net/move/sweet-kiss
# https://pokemondb.net/move/sweet-scent
# https://pokemondb.net/move/swift
# https://pokemondb.net/move/switcheroo
# https://pokemondb.net/move/swords-dance
# https://pokemondb.net/move/synchronoise
# https://pokemondb.net/move/synthesis
# https://pokemondb.net/move/tackle
# https://pokemondb.net/move/tail-glow
# https://pokemondb.net/move/tail-slap
# https://pokemondb.net/move/tail-whip
# https://pokemondb.net/move/tailwind
# https://pokemondb.net/move/take-down
# https://pokemondb.net/move/take-heart
# https://pokemondb.net/move/tar-shot
# https://pokemondb.net/move/taunt
# https://pokemondb.net/move/tearful-look
# https://pokemondb.net/move/teatime
# https://pokemondb.net/move/techno-blast
# https://pokemondb.net/move/tectonic-rage
# https://pokemondb.net/move/teeter-dance
# https://pokemondb.net/move/telekinesis
# https://pokemondb.net/move/teleport
# https://pokemondb.net/move/terrain-pulse
# https://pokemondb.net/move/thief
# https://pokemondb.net/move/thousand-arrows
# https://pokemondb.net/move/thousand-waves
# https://pokemondb.net/move/thrash
# https://pokemondb.net/move/throat-chop
# https://pokemondb.net/move/thunder
# https://pokemondb.net/move/thunder-cage
# https://pokemondb.net/move/thunder-fang
# https://pokemondb.net/move/thunder-punch
# https://pokemondb.net/move/thunder-shock
# https://pokemondb.net/move/thunder-wave
# https://pokemondb.net/move/thunderbolt
# https://pokemondb.net/move/thunderous-kick
# https://pokemondb.net/move/tickle
# https://pokemondb.net/move/topsy-turvy
# https://pokemondb.net/move/torment
# https://pokemondb.net/move/toxic
# https://pokemondb.net/move/toxic-spikes
# https://pokemondb.net/move/toxic-thread
# https://pokemondb.net/move/transform
# https://pokemondb.net/move/tri-attack
# https://pokemondb.net/move/trick
# https://pokemondb.net/move/trick-room
# https://pokemondb.net/move/trick-or-treat
# https://pokemondb.net/move/triple-arrows
# https://pokemondb.net/move/triple-axel
# https://pokemondb.net/move/triple-kick
# https://pokemondb.net/move/trop-kick
# https://pokemondb.net/move/trump-card
# https://pokemondb.net/move/twineedle
# https://pokemondb.net/move/twinkle-tackle
# https://pokemondb.net/move/twister
# https://pokemondb.net/move/u-turn
# https://pokemondb.net/move/uproar
# https://pokemondb.net/move/v-create
# https://pokemondb.net/move/vacuum-wave
# https://pokemondb.net/move/veevee-volley
# https://pokemondb.net/move/venom-drench
# https://pokemondb.net/move/venoshock
# https://pokemondb.net/move/victory-dance
# https://pokemondb.net/move/vine-whip
# https://pokemondb.net/move/vise-grip
# https://pokemondb.net/move/vital-throw
# https://pokemondb.net/move/volt-switch
# https://pokemondb.net/move/volt-tackle
# https://pokemondb.net/move/wake-up-slap
# https://pokemondb.net/move/water-gun
# https://pokemondb.net/move/water-pledge
# https://pokemondb.net/move/water-pulse
# https://pokemondb.net/move/water-shuriken
# https://pokemondb.net/move/water-sport
# https://pokemondb.net/move/water-spout
# https://pokemondb.net/move/waterfall
# https://pokemondb.net/move/wave-crash
# https://pokemondb.net/move/weather-ball
# https://pokemondb.net/move/whirlpool
# https://pokemondb.net/move/whirlwind
# https://pokemondb.net/move/wicked-blow
# https://pokemondb.net/move/wide-guard
# https://pokemondb.net/move/wild-charge
# https://pokemondb.net/move/wildbolt-storm
# https://pokemondb.net/move/will-o-wisp
# https://pokemondb.net/move/wing-attack
# https://pokemondb.net/move/wish
# https://pokemondb.net/move/withdraw
# https://pokemondb.net/move/wonder-room
# https://pokemondb.net/move/wood-hammer
# https://pokemondb.net/move/work-up
# https://pokemondb.net/move/worry-seed
# https://pokemondb.net/move/wrap
# https://pokemondb.net/move/wring-out
# https://pokemondb.net/move/x-scissor
# https://pokemondb.net/move/yawn
# https://pokemondb.net/move/zap-cannon
# https://pokemondb.net/move/zen-headbutt
# https://pokemondb.net/move/zing-zap
# https://pokemondb.net/move/zippy-zap
