# %%
## load in the lib
import requests
from bs4 import BeautifulStoneSoup as bs
import pandas as pd

# %% [markdown]
# Load in the webpage

# %%
# load webpage content
r = requests.get("https://pokemondb.net/move/will-o-wisp")

#convert to a bsoup object
soup = bs(r.content)

#print html
print(soup)

# %% [markdown]
# Using Bsoup to scrape

# %%
#searchs page for the body stuff
body = soup.find('body')
#searchs the body for examples of the a tag with the class ent-name. This gives us the names of hte pokemon that can learn the move
pokeNames = body.find_all('a', {'class':'ent-name'})
for title in pokeNames:
    print(title.text)

# %%
## load in the lib
import requests
from bs4 import BeautifulStoneSoup as bs

# load webpage content
r = requests.get("https://pokemondb.net/move/all")

#convert to a bsoup object
soupymoves = bs(r.content)

pokeMoves = soupymoves.find_all('a', {'class':'ent-name'})
for title in pokeMoves:
    print(title.text)

len(pokeMoves)

# %% [markdown]
# url getter

# %%
# import necessary libraries
from bs4 import BeautifulSoup
import requests
import re
  
  
# function to extract html document from given url
def getHTMLdocument(url):
      
    # request for HTML document of given url
    response = requests.get(url)
      
    # response will be provided in JSON format
    return response.text
  
    
# assign required credentials
# assign URL
url_to_scrape = "https://pokemondb.net/move/all"
  
# create document
html_document = getHTMLdocument(url_to_scrape)
  
# create soap object
soup = BeautifulSoup(html_document, 'html.parser')
  
  
# find all the anchor tags with "ent-name" 
# attribute starting with "/move/(whatevermove)"
for link in soup.find_all('a',
                            attrs={'href': re.compile("/move/")}):
    # display the actual urls?????????
    links = (link.get('href'))
    listOfLinks = ( "https://pokemondb.net" + links)
    print(listOfLinks)

# %% [markdown]
# putting it all together

# %%
# import necessary libraries
from bs4 import BeautifulSoup as bs
import requests
import re
import csv

move_dict = {}

def who_can_learn_me():
    body = soup.find('body')
    #searchs the body for examples of the a tag with the class ent-name. This gives us the names of hte pokemon that can learn the move
    pokeNames = body.find_all('a', {'class':'ent-name'})
    for title in pokeNames:
        print(title.text)

# function to extract html document from given url
def getHTMLdocument(url):
    # request for HTML document of given url
    response = requests.get(url)
    # response will be provided in JSON format
    return response.text

# assign required credentials
# assign URL
url_to_scrape = "https://pokemondb.net/move/all"
# create document
html_document = getHTMLdocument(url_to_scrape)
# create soap object
soup = bs(html_document, 'html.parser')
# find all the anchor tags with "ent-name" 
# attribute starting with "/move/(whatevermove)"
for link in soup.find_all('a',
                            attrs={'href': re.compile("/move/")}):
    # display the actual urls?????????
    links = (link.get('href'))
    listOfLinks =( "https://pokemondb.net" + links)
    ##print(listOfLinks)
  
    # load webpage content
    r = requests.get(listOfLinks)

    #convert to a bsoup object
    soup = bs(r.content)
    #print html
    #print(soup)
    #searchs page for the body stuff
    body = soup.find('body')
    #searchs the body for examples of the a tag with the class ent-name. This gives us the names of hte pokemon that can learn the move
    pokeNames = body.find_all('a', {'class':'ent-name'})


    move_dict[links[6:]] = []

    for title in pokeNames:
        # the_end = (links[6:] + " " + title.text)
        move_dict[links[6:]].append(title.text)
    for key in move_dict:
        print( key ,move_dict[key])
# Out:
# 10000000-volt-thunderbolt []
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# acrobatics ['Emolga', 'Fletchling', 'Fletchinder', 'Talonflame', 'Inteleon', 'Flapple', 'Charmander', 'Charmeleon', 'Charizard', 'Butterfree', 'Zubat', 'Golbat', "Farfetch'd", 'Scyther', 'Zapdos', 'Mew', 'Crobat', 'Scizor', 'Mantine', 'Treecko', 'Grovyle', 'Sceptile', 'Blaziken', 'Ninjask', 'Lunatone', 'Solrock', 'Vespiquen', 'Drifloon', 'Drifblim', 'Lopunny', 'Mantyke', 'Uxie', 'Mesprit', 'Azelf', 'Woobat', 'Swoobat', 'Archen', 'Archeops', 'Emolga', 'Cryogonal', 'Mienfoo', 'Mienshao', 'Hydreigon', 'Larvesta', 'Volcarona', 'Tornadus', 'Tornadus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Hawlucha', 'Noibat', 'Noivern', 'Yveltal', 'Decidueye', 'Litten', 'Torracat', 'Incineroar', 'Popplio', 'Brionne', 'Primarina', 'Grubbin', 'Charjabug', 'Vikavolt', 'Cutiefly', 'Ribombee', 'Salazzle', 'Tsareena', 'Comfey', 'Passimian', 'Tapu Koko', 'Lunala', 'Celesteela', 'Marshadow', 'Naganadel', 'Zeraora', 'Grookey', 'Thwackey', 'Rillaboom', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Thievul', 'Flapple', 'Frosmoth', 'Drakloak', 'Dragapult', 'Kubfu', 'Urshifu', 'Urshifu', 'Zarude', 'Regieleki']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# acrobatics ['Emolga', 'Fletchling', 'Fletchinder', 'Talonflame', 'Inteleon', 'Flapple', 'Charmander', 'Charmeleon', 'Charizard', 'Butterfree', 'Zubat', 'Golbat', "Farfetch'd", 'Scyther', 'Zapdos', 'Mew', 'Crobat', 'Scizor', 'Mantine', 'Treecko', 'Grovyle', 'Sceptile', 'Blaziken', 'Ninjask', 'Lunatone', 'Solrock', 'Vespiquen', 'Drifloon', 'Drifblim', 'Lopunny', 'Mantyke', 'Uxie', 'Mesprit', 'Azelf', 'Woobat', 'Swoobat', 'Archen', 'Archeops', 'Emolga', 'Cryogonal', 'Mienfoo', 'Mienshao', 'Hydreigon', 'Larvesta', 'Volcarona', 'Tornadus', 'Tornadus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Hawlucha', 'Noibat', 'Noivern', 'Yveltal', 'Decidueye', 'Litten', 'Torracat', 'Incineroar', 'Popplio', 'Brionne', 'Primarina', 'Grubbin', 'Charjabug', 'Vikavolt', 'Cutiefly', 'Ribombee', 'Salazzle', 'Tsareena', 'Comfey', 'Passimian', 'Tapu Koko', 'Lunala', 'Celesteela', 'Marshadow', 'Naganadel', 'Zeraora', 'Grookey', 'Thwackey', 'Rillaboom', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Thievul', 'Flapple', 'Frosmoth', 'Drakloak', 'Dragapult', 'Kubfu', 'Urshifu', 'Urshifu', 'Zarude', 'Regieleki']
# acupressure ['Qwilfish', 'Skorupi', 'Drapion', 'Maractus', 'Pincurchin', 'Tentacool', 'Tentacruel', 'Goldeen', 'Seaking', 'Shuckle', 'Inkay', 'Malamar', 'Bounsweet', 'Steenee', 'Tsareena', 'Arrokuda', 'Barraskewda']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# acrobatics ['Emolga', 'Fletchling', 'Fletchinder', 'Talonflame', 'Inteleon', 'Flapple', 'Charmander', 'Charmeleon', 'Charizard', 'Butterfree', 'Zubat', 'Golbat', "Farfetch'd", 'Scyther', 'Zapdos', 'Mew', 'Crobat', 'Scizor', 'Mantine', 'Treecko', 'Grovyle', 'Sceptile', 'Blaziken', 'Ninjask', 'Lunatone', 'Solrock', 'Vespiquen', 'Drifloon', 'Drifblim', 'Lopunny', 'Mantyke', 'Uxie', 'Mesprit', 'Azelf', 'Woobat', 'Swoobat', 'Archen', 'Archeops', 'Emolga', 'Cryogonal', 'Mienfoo', 'Mienshao', 'Hydreigon', 'Larvesta', 'Volcarona', 'Tornadus', 'Tornadus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Hawlucha', 'Noibat', 'Noivern', 'Yveltal', 'Decidueye', 'Litten', 'Torracat', 'Incineroar', 'Popplio', 'Brionne', 'Primarina', 'Grubbin', 'Charjabug', 'Vikavolt', 'Cutiefly', 'Ribombee', 'Salazzle', 'Tsareena', 'Comfey', 'Passimian', 'Tapu Koko', 'Lunala', 'Celesteela', 'Marshadow', 'Naganadel', 'Zeraora', 'Grookey', 'Thwackey', 'Rillaboom', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Thievul', 'Flapple', 'Frosmoth', 'Drakloak', 'Dragapult', 'Kubfu', 'Urshifu', 'Urshifu', 'Zarude', 'Regieleki']
# acupressure ['Qwilfish', 'Skorupi', 'Drapion', 'Maractus', 'Pincurchin', 'Tentacool', 'Tentacruel', 'Goldeen', 'Seaking', 'Shuckle', 'Inkay', 'Malamar', 'Bounsweet', 'Steenee', 'Tsareena', 'Arrokuda', 'Barraskewda']
# aerial-ace ["Farfetch'd", 'Heracross', 'Torchic', 'Combusken', 'Blaziken', 'Ninjask', 'Gallade', 'Rufflet', 'Braviary', 'Fletchling', 'Fletchinder', 'Talonflame', 'Honedge', 'Doublade', 'Aegislash', 'Aegislash', 'Hawlucha', 'Type: Null', 'Silvally', 'Kartana', 'Dracozolt', 'Kubfu', 'Urshifu', 'Urshifu', 'Togepi', 'Togetic', 'Wingull', 'Pelipper', 'Togekiss', 'Cramorant']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# acrobatics ['Emolga', 'Fletchling', 'Fletchinder', 'Talonflame', 'Inteleon', 'Flapple', 'Charmander', 'Charmeleon', 'Charizard', 'Butterfree', 'Zubat', 'Golbat', "Farfetch'd", 'Scyther', 'Zapdos', 'Mew', 'Crobat', 'Scizor', 'Mantine', 'Treecko', 'Grovyle', 'Sceptile', 'Blaziken', 'Ninjask', 'Lunatone', 'Solrock', 'Vespiquen', 'Drifloon', 'Drifblim', 'Lopunny', 'Mantyke', 'Uxie', 'Mesprit', 'Azelf', 'Woobat', 'Swoobat', 'Archen', 'Archeops', 'Emolga', 'Cryogonal', 'Mienfoo', 'Mienshao', 'Hydreigon', 'Larvesta', 'Volcarona', 'Tornadus', 'Tornadus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Hawlucha', 'Noibat', 'Noivern', 'Yveltal', 'Decidueye', 'Litten', 'Torracat', 'Incineroar', 'Popplio', 'Brionne', 'Primarina', 'Grubbin', 'Charjabug', 'Vikavolt', 'Cutiefly', 'Ribombee', 'Salazzle', 'Tsareena', 'Comfey', 'Passimian', 'Tapu Koko', 'Lunala', 'Celesteela', 'Marshadow', 'Naganadel', 'Zeraora', 'Grookey', 'Thwackey', 'Rillaboom', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Thievul', 'Flapple', 'Frosmoth', 'Drakloak', 'Dragapult', 'Kubfu', 'Urshifu', 'Urshifu', 'Zarude', 'Regieleki']
# acupressure ['Qwilfish', 'Skorupi', 'Drapion', 'Maractus', 'Pincurchin', 'Tentacool', 'Tentacruel', 'Goldeen', 'Seaking', 'Shuckle', 'Inkay', 'Malamar', 'Bounsweet', 'Steenee', 'Tsareena', 'Arrokuda', 'Barraskewda']
# aerial-ace ["Farfetch'd", 'Heracross', 'Torchic', 'Combusken', 'Blaziken', 'Ninjask', 'Gallade', 'Rufflet', 'Braviary', 'Fletchling', 'Fletchinder', 'Talonflame', 'Honedge', 'Doublade', 'Aegislash', 'Aegislash', 'Hawlucha', 'Type: Null', 'Silvally', 'Kartana', 'Dracozolt', 'Kubfu', 'Urshifu', 'Urshifu', 'Togepi', 'Togetic', 'Wingull', 'Pelipper', 'Togekiss', 'Cramorant']
# aeroblast ['Lugia']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# acrobatics ['Emolga', 'Fletchling', 'Fletchinder', 'Talonflame', 'Inteleon', 'Flapple', 'Charmander', 'Charmeleon', 'Charizard', 'Butterfree', 'Zubat', 'Golbat', "Farfetch'd", 'Scyther', 'Zapdos', 'Mew', 'Crobat', 'Scizor', 'Mantine', 'Treecko', 'Grovyle', 'Sceptile', 'Blaziken', 'Ninjask', 'Lunatone', 'Solrock', 'Vespiquen', 'Drifloon', 'Drifblim', 'Lopunny', 'Mantyke', 'Uxie', 'Mesprit', 'Azelf', 'Woobat', 'Swoobat', 'Archen', 'Archeops', 'Emolga', 'Cryogonal', 'Mienfoo', 'Mienshao', 'Hydreigon', 'Larvesta', 'Volcarona', 'Tornadus', 'Tornadus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Hawlucha', 'Noibat', 'Noivern', 'Yveltal', 'Decidueye', 'Litten', 'Torracat', 'Incineroar', 'Popplio', 'Brionne', 'Primarina', 'Grubbin', 'Charjabug', 'Vikavolt', 'Cutiefly', 'Ribombee', 'Salazzle', 'Tsareena', 'Comfey', 'Passimian', 'Tapu Koko', 'Lunala', 'Celesteela', 'Marshadow', 'Naganadel', 'Zeraora', 'Grookey', 'Thwackey', 'Rillaboom', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Thievul', 'Flapple', 'Frosmoth', 'Drakloak', 'Dragapult', 'Kubfu', 'Urshifu', 'Urshifu', 'Zarude', 'Regieleki']
# acupressure ['Qwilfish', 'Skorupi', 'Drapion', 'Maractus', 'Pincurchin', 'Tentacool', 'Tentacruel', 'Goldeen', 'Seaking', 'Shuckle', 'Inkay', 'Malamar', 'Bounsweet', 'Steenee', 'Tsareena', 'Arrokuda', 'Barraskewda']
# aerial-ace ["Farfetch'd", 'Heracross', 'Torchic', 'Combusken', 'Blaziken', 'Ninjask', 'Gallade', 'Rufflet', 'Braviary', 'Fletchling', 'Fletchinder', 'Talonflame', 'Honedge', 'Doublade', 'Aegislash', 'Aegislash', 'Hawlucha', 'Type: Null', 'Silvally', 'Kartana', 'Dracozolt', 'Kubfu', 'Urshifu', 'Urshifu', 'Togepi', 'Togetic', 'Wingull', 'Pelipper', 'Togekiss', 'Cramorant']
# aeroblast ['Lugia']
# after-you ['Clefairy', 'Clefable', 'Moltres', 'Togepi', 'Togetic', 'Buneary', 'Lopunny', 'Togekiss', 'Audino', 'Petilil', 'Lilligant', 'Maractus', 'Minccino', 'Cinccino', 'Oranguru', 'Orbeetle', 'Mr. Rime', 'Indeedee', 'Oddish', 'Gloom', 'Vileplume', 'Bellossom', 'Wooper', 'Quagsire', 'Lillipup', 'Herdier', 'Stoutland', 'Spritzee', 'Aromatisse', 'Swirlix', 'Slurpuff', 'Comfey', 'Hatenna', 'Hattrem', 'Hatterene']
# 10000000-volt-thunderbolt []
# absorb ['Zubat', 'Golbat', 'Oddish', 'Gloom', 'Vileplume', 'Exeggcute', 'Exeggutor', 'Exeggutor', 'Tangela', 'Kabuto', 'Kabutops', 'Crobat', 'Bellossom', 'Lotad', 'Lombre', 'Ludicolo', 'Seedot', 'Nuzleaf', 'Shiftry', 'Nincada', 'Ninjask', 'Shedinja', 'Roselia', 'Budew', 'Roserade', 'Tangrowth', 'Cottonee', 'Whimsicott', 'Petilil', 'Lilligant', 'Maractus', 'Foongus', 'Amoonguss', 'Frillish', 'Jellicent', 'Joltik', 'Galvantula', 'Shelmet', 'Accelgor', 'Goomy', 'Sliggoo', 'Goodra', 'Noibat', 'Noivern', 'Cutiefly', 'Ribombee', 'Morelull', 'Shiinotic', 'Sandygast', 'Palossand', 'Dhelmise', 'Celesteela', 'Treecko', 'Larvesta', 'Volcarona']
# accelerock ['Lycanroc', 'Lycanroc']
# acid ['Oddish', 'Gloom', 'Vileplume', 'Tentacool', 'Tentacruel', 'Slowpoke', 'Slowbro', 'Bellossom', 'Slowking', 'Lileep', 'Cradily', 'Tympole', 'Palpitoad', 'Seismitoad', 'Shelmet', 'Accelgor', 'Skrelp', 'Dragalge', 'Nihilego', 'Poipole', 'Naganadel', 'Toxel', 'Toxtricity', 'Toxtricity', 'Shuckle']
# acid-armor ['Tentacool', 'Tentacruel', 'Vaporeon', 'Vanillite', 'Vanillish', 'Vanilluxe', 'Jellicent', 'Cryogonal', 'Shelmet', 'Accelgor', 'Meltan', 'Melmetal', 'Milcery', 'Alcremie', 'Shellos', 'Gastrodon', 'Solosis', 'Duosion', 'Reuniclus', 'Frillish', 'Jellicent', 'Litwick', 'Lampent', 'Chandelure', 'Skrelp', 'Dragalge']
# acid-downpour []
# acid-spray ['Stunky', 'Skuntank', 'Trubbish', 'Garbodor', 'Karrablast', 'Escavalier', 'Accelgor', 'Sliggoo', 'Goodra', 'Nihilego', 'Flapple', 'Toxtricity', 'Toxtricity', 'Wooper', 'Quagsire', 'Qwilfish', 'Remoraid', 'Octillery', 'Scraggy', 'Scrafty', 'Ferroseed', 'Ferrothorn']
# acrobatics ['Emolga', 'Fletchling', 'Fletchinder', 'Talonflame', 'Inteleon', 'Flapple', 'Charmander', 'Charmeleon', 'Charizard', 'Butterfree', 'Zubat', 'Golbat', "Farfetch'd", 'Scyther', 'Zapdos', 'Mew', 'Crobat', 'Scizor', 'Mantine', 'Treecko', 'Grovyle', 'Sceptile', 'Blaziken', 'Ninjask', 'Lunatone', 'Solrock', 'Vespiquen', 'Drifloon', 'Drifblim', 'Lopunny', 'Mantyke', 'Uxie', 'Mesprit', 'Azelf', 'Woobat', 'Swoobat', 'Archen', 'Archeops', 'Emolga', 'Cryogonal', 'Mienfoo', 'Mienshao', 'Hydreigon', 'Larvesta', 'Volcarona', 'Tornadus', 'Tornadus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Hawlucha', 'Noibat', 'Noivern', 'Yveltal', 'Decidueye', 'Litten', 'Torracat', 'Incineroar', 'Popplio', 'Brionne', 'Primarina', 'Grubbin', 'Charjabug', 'Vikavolt', 'Cutiefly', 'Ribombee', 'Salazzle', 'Tsareena', 'Comfey', 'Passimian', 'Tapu Koko', 'Lunala', 'Celesteela', 'Marshadow', 'Naganadel', 'Zeraora', 'Grookey', 'Thwackey', 'Rillaboom', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Thievul', 'Flapple', 'Frosmoth', 'Drakloak', 'Dragapult', 'Kubfu', 'Urshifu', 'Urshifu', 'Zarude', 'Regieleki']
# acupressure ['Qwilfish', 'Skorupi', 'Drapion', 'Maractus', 'Pincurchin', 'Tentacool', 'Tentacruel', 'Goldeen', 'Seaking', 'Shuckle', 'Inkay', 'Malamar', 'Bounsweet', 'Steenee', 'Tsareena', 'Arrokuda', 'Barraskewda']
# aerial-ace ["Farfetch'd", 'Heracross', 'Torchic', 'Combusken', 'Blaziken', 'Ninjask', 'Gallade', 'Rufflet', 'Braviary', 'Fletchling', 'Fletchinder', 'Talonflame', 'Honedge', 'Doublade', 'Aegislash', 'Aegislash', 'Hawlucha', 'Type: Null', 'Silvally', 'Kartana', 'Dracozolt', 'Kubfu', 'Urshifu', 'Urshifu', 'Togepi', 'Togetic', 'Wingull', 'Pelipper', 'Togekiss', 'Cramorant']
# aeroblast ['Lugia']
# after-you ['Clefairy', 'Clefable', 'Moltres', 'Togepi', 'Togetic', 'Buneary', 'Lopunny', 'Togekiss', 'Audino', 'Petilil', 'Lilligant', 'Maractus', 'Minccino', 'Cinccino', 'Oranguru', 'Orbeetle', 'Mr. Rime', 'Indeedee', 'Oddish', 'Gloom', 'Vileplume', 'Bellossom', 'Wooper', 'Quagsire', 'Lillipup', 'Herdier', 'Stoutland', 'Spritzee', 'Aromatisse', 'Swirlix', 'Slurpuff', 'Comfey', 'Hatenna', 'Hattrem', 'Hatterene']
# agility ['Pikachu', 'Raichu', 'Raichu', 'Sandshrew', 'Growlithe', 'Arcanine', 'Ponyta', 'Ponyta', 'Rapidash', 'Rapidash', "Farfetch'd", 'Hitmonchan', 'Horsea', 'Seadra', 'Goldeen', 'Seaking', 'Scyther', 'Jolteon', 'Porygon', 'Aerodactyl', 'Articuno', 'Articuno', 'Zapdos', 'Zapdos', 'Moltres', 'Moltres', 'Dratini', 'Dragonair', 'Dragonite', 'Scizor', 'Sneasel', 'Mantine', 'Skarmory', 'Kingdra', 'Porygon2', 'Hitmontop', 'Wingull', 'Pelipper', 'Ninjask', 'Carvanha', 'Sharpedo', 'Metang', 'Metagross', 'Buneary', 'Lopunny', 'Mantyke', 'Weavile', 'Porygon-Z', 'Venipede', 'Whirlipede', 'Scolipede', 'Archen', 'Archeops', 'Zorua', 'Zoroark', 'Emolga', 'Joltik', 'Galvantula', 'Accelgor', 'Durant', 'Tornadus', 'Tornadus', 'Thundurus', 'Thundurus', 'Fletchling', 'Fletchinder', 'Talonflame', 'Vikavolt', 'Tapu Koko', 'Pheromosa', 'Zeraora', 'Scorbunny', 'Raboot', 'Cinderace', 'Orbeetle', 'Arrokuda', 'Barraskewda', 'Morpeko', 'Drakloak', 'Dragapult', 'Eternatus', 'Spectrier', 'Calyrex', 'Pikachu', 'Raichu', 'Raichu', 'Sandshrew', 'Sandslash', 'Sandslash', 'Vulpix', 'Vulpix', 'Ninetales', 'Ninetales', 'Zubat', 'Golbat', 'Diglett', 'Diglett', 'Dugtrio', 'Dugtrio', 'Growlithe', 'Arcanine', 'Ponyta', 'Ponyta', 'Rapidash', 'Rapidash', "Farfetch'd", 'Krabby', 'Kingler', 'Hitmonchan', 'Horsea', 'Seadra', 'Goldeen', 'Seaking', 'Starmie', 'Scyther', 'Jolteon', 'Porygon', 'Aerodactyl', 'Articuno', 'Articuno', 'Zapdos', 'Zapdos', 'Moltres', 'Moltres', 'Dratini', 'Dragonair', 'Dragonite', 'Mewtwo', 'Mew', 'Hoothoot', 'Noctowl', 'Crobat', 'Chinchou', 'Lanturn', 'Dunsparce', 'Scizor', 'Sneasel', 'Delibird', 'Mantine', 'Skarmory', 'Kingdra', 'Porygon2', 'Hitmontop', 'Raikou', 'Entei', 'Suicune', 'Treecko', 'Grovyle', 'Sceptile', 'Torchic', 'Combusken', 'Blaziken', 'Wingull', 'Pelipper', 'Ninjask', 'Shedinja', 'Electrike', 'Manectric', 'Carvanha', 'Sharpedo', 'Swablu', 'Altaria', 'Metang', 'Metagross', 'Latias', 'Latios', 'Luxray', 'Buneary', 'Lopunny', 'Riolu', 'Lucario', 'Skorupi', 'Drapion', 'Mantyke', 'Weavile', 'Porygon-Z', 'Pidove', 'Tranquill', 'Unfezant', 'Venipede', 'Whirlipede', 'Scolipede', 'Basculin', 'Archen', 'Archeops', 'Zorua', 'Zoroark', 'Emolga', 'Escavalier', 'Joltik', 'Galvantula', 'Elgyem', 'Beheeyem', 'Accelgor', 'Mienfoo', 'Mienshao', 'Rufflet', 'Braviary', 'Durant', 'Tornadus', 'Tornadus', 'Thundurus', 'Thundurus', 'Bunnelby', 'Diggersby', 'Fletchling', 'Fletchinder', 'Talonflame', 'Helioptile', 'Heliolisk', 'Hawlucha', 'Noibat', 'Noivern', 'Vikavolt', 'Lycanroc', 'Togedemaru', 'Tapu Koko', 'Solgaleo', 'Lunala', 'Pheromosa', 'Magearna', 'Marshadow', 'Zeraora', 'Scorbunny', 'Raboot', 'Cinderace', 'Inteleon', 'Rookidee', 'Corvisquire', 'Corviknight', 'Orbeetle', 'Nickit', 'Thievul', 'Wooloo', 'Dubwool', 'Boltund', 'Cramorant', 'Arrokuda', 'Barraskewda', 'Falinks', 'Eiscue', 'Morpeko', 'Drakloak', 'Dragapult', 'Zacian', 'Zamazenta', 'Eternatus', 'Regieleki', 'Spectrier', 'Calyrex', 'Calyrex', 'Calyrex']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\franc\OneDrive\Documents\HCI584X\PokemonDataScience_HCI_584_Francis\scrape_for_move data.ipynb Cell 10 in <cell line: 32>()
#      <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=35'>36</a> listOfLinks =( "https://pokemondb.net" + links)
#      <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=36'>37</a> ##print(listOfLinks)
#      <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=37'>38</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=38'>39</a> # load webpage content
# ---> <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=39'>40</a> r = requests.get(listOfLinks)
#      <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=41'>42</a> #convert to a bsoup object
#      <a href='vscode-notebook-cell:/c%3A/Users/franc/OneDrive/Documents/HCI584X/PokemonDataScience_HCI_584_Francis/scrape_for_move%20data.ipynb#ch0000009?line=42'>43</a> soup = bs(r.content)
#
# File c:\Users\franc\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File c:\Users\franc\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\franc\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File c:\Users\franc\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File c:\Users\franc\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File c:\Users\franc\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\franc\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\franc\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\franc\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\franc\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\franc\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\franc\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\franc\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\franc\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:
